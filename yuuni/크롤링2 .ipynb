# %% [raw]
# from urllib.request import urlopen
# from bs4 import BeautifulSoup
# html = urlopen('http://www.pythonscraping.com/pages/warandpeace.html')
# bs = BeautifulSoup(html, 'html.parser')
# print(bs)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://www.pythonscraping.com/pages/warandpeace.html')
bs = BeautifulSoup(html, "html.parser")

# %% [raw]
# nameList = bs.findAll('span', {'class': 'green'})
# for name in nameList:
#     print(name.get_text())

# %%
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print([title for title in titles])

# %%
allText = bs.find_all('span', {'class':{'green', 'red'}})#span class green 
print([text for text in allText])

# %%
nameList = bs.find_all(text='the prince')
print(len(nameList))

# %%
title = bs.find_all(id='title', class_='text')
print([text for text in allText])

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')

for child in bs.find('table',{'id':'giftList'}).children:
    print(child)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# ...

# %%
for i in bs.find('table',{id:'giftList'}).children:
    try:
        print(i.findAll('td')[1])
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7632\1454884529.py in <module>
# ----> 1 for i in bs.find('table',{id:'giftList'}).children:
#       2     try:
#       3         print(i.findAll('td')[1])
#       4     except:
#       5         pass
#
# AttributeError: 'NoneType' object has no attribute 'children'

# %%
bs.find('img',{'src':'../img/gifts/img2.jpg'}).parent.previous_sibling.get_text()
# Out:
# '\n$10,000.52\n'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')

for sibling in bs.find('table', {'id':'giftList'}).tr.next_siblings:
    print(sibling)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('img',
              {'src':'../img/gifts/img1.jpg'})
      .parent.previous_sibling.get_text())

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'src':re.compile('\.\.\/img\/gifts/img.*\.jpg')})
for image in images: 
    print(image['src'])

# %%
bs.find_all(lambda tag: len(tag.attrs) == 2)
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>,
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
# ...

# %%
bs.find_all(lambda tag: tag.get_text() == 'Or maybe he\'s only resting?')
# Out:
# [<span class="excitingNote">Or maybe he's only resting?</span>]

# %%
bs.find_all('', text='Or maybe he\'s only resting?')
# Out:
# ["Or maybe he's only resting?"]

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "http://192.168.0.44:8000/aaa/"
html = urlopen(url)
bs = BeautifulSoup(html,'html.parser')
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Document</title>
# </head>
# <body>
# <li><a href="https://naver.com">네이버</a></li>
# <li><a href="https://daum.net">다음</a></li>
# <li><a href="http://donga.com" style="color:red">동아일보</a></li>
# </body>
# </html>

# %%
for link in bs.find_all('a'):
    print(link.text)
for link in bs.find_all('a'):
    try:
        print(link['style'])
    except:
        pass
# Out:
# 네이버
# 다음
# 동아일보
# color:red

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 
url = 'http://en.wikipedia.org/wiki/Kevin_Bacon'
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
links = []
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        links.append(link.attrs['href'])

# %%
inner_link = []
outer_link = []
for link in links:
    if '/wiki' in link:
# Out:
#   File "C:\Users\bjlov\AppData\Local\Temp\ipykernel_7632\3305846887.py", line 5
#
#     ^
# IndentationError: expected an indented block

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

url = 'http://en.wikipedia.org/wiki/Kevin_Bacon'
html = urlopen(url)


bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/The_River_Wild
# /wiki/Sleepers_(film)
# /wiki/Wild_Things_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Flatliners
# /wiki/Crazy,_Stupid,_Love
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0])
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# Main Page
# ...

# %%
# from urlib.request import urlopen
# from bs4 import BeautifulSoup
# 'Kevin_bacon'
# def get_link(url):
#     base_url = 'https://en.wikipedia.org/wiki/'
#     url = base_url+url
#     html = urlopen(url)
#     bs = BeautifulSoup(html, 'html_parser')
#     inner_link = bs.find_all('a', {href=re.compile('^(/wiki/)')})
#     inner_href = []
#     for inner_link in inner_links:
#         href = url+inner_link['href']
#         inner_href.append(href)
#     return inner_href
from urllib.request import urlopen
from bs4 import BeautifulSoup
'Kevin_Bacon'
def get_link(url):
    base_url = 'http://en.wikipedia.org/wiki/'
    url = base_url+url
    html = urlopen(url)
    bs = BeautifulSoup(html,'html.parser')
    inner_links = bs.find_all('a', href=re.compile('^(/wiki/)'))
    inner_href = []
    for inner_link in inner_links:
        href = url+inner_link['href']
        inner_href.append(href)
        
    
    return inner_href

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/w/index.php?search=Kevin+bacon&title=Special%3ASearch&fulltext=1&ns0=1'
html = urlopen(url)
html = urlopen
