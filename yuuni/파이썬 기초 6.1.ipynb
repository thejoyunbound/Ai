# %%
class Student_score:
    def __init__(self):
        self.member = {}
        self.login()
        
    def login(self):
        self.id_ = input('아이디를 입력하세요')
        self.password = input('비밀번호를 입력하세요')
        self.student_manage()
    
    def student_manage(self):
        if self.id_ == 'admin':
            if self.password == '0000':
                check = 1
            else:
                check = 2
        else:
            check = 3    
 
        information = """
        메뉴
        ================
        성적 조회 : 1 
        성적 입력 : 2
        학번 조회 : 3
        ================
        """
        print(information)
        
        if check == 1: 
            method = input('작업을 선택하세요')
            if method == '1':
                search = input('전체조회는 0, 학번조회는 해당이름을 입력하세요')

                if search == '0':
                    self.check_no()
                else:
                    self.check_no(search)

            elif method == '2':
                member = 0
                while True:
                    name = input('이름을 입력하세요')
                    password = input('학생비밀번를 입력하세요')
                    korean = input('국어 성적을 입력하세요')
                    english = input('영어 성적을 입력하세요')
                    math = input('수학성적을 입력하세요')
                    self.student_add(name,password,int(korean), int(english),int(math))
                    member += 1
                    x = input('계속하시려면 엔터키를 치시고 끝내시려면 아무 문자나 입력하세요')
                    if x != '':
                        print(f'{member}명의 입력이 완료 되었습니다')
                        break


            elif method == '3':
                search = input('전체조회는 0번 학번조회는 학번을 입력하세요')
                search = int(search)
                if search == 0:
                    self.student_print()
                else:
                    self.student_print(search)
                    
        elif check == 2:
            self.login()   
        elif check == 3:
            self.id_ = int(self.id_)
            if self.member.get(self.id_) != None:
                if self.member.get(self.id_)['password'] == self.password:
                    self.student_print(self.id_)
                    if self.member.get(self.id_)
                    
                    password_confirm = input('비밀번호를 변경하시려면 y를 입력하세요')
                    if password_confirm == 'y':
                        changed_password = input
                else:
                    print('비밀번호를 확인하세요')
            else:
                print(f'{self.id_} 학번은 등록이 안되어 있습니다 관리자에게 확인하세요')
                    
                
    def student_add(self,name,password,korean,english,math):
        key = len(self.member.keys())+1
        new_student = {'name':name,
                       'password':password,
                       'korean':korean,
                       'english':english,
                       'math':math
                      }
        self.member[key] = new_student
    def student_print(self,x=0):
        if len(self.member) == 0:
            print('아직 아무 학생도 입력이 되지 않았습니다')
            print('메뉴 화면으로 돌아 갑니다 2번을 입력하여')
            print('학생을 먼저 입력하도록 하세요')
            self.student_manage()
        if x == 0:
            for v in self.member.values():
                name = v['name']
                total = v['korean'] + v['english'] + v['math']
                avg = total/3
                print(f'이름 : {name} 총점 {total} 평균 {avg}')
        else:
            name = self.member[x]['name']
            korean = self.member[x]['korean']
            english = self.member[x]['english']
            math = self.member[x]['math']
            total = korean+english+math
            avg = total/3
            print(f'{name}의 성적은 총점{total} 평균{avg}입니다')
    
    def subject_total(self):
        korean = 0
        english = 0
        math = 0
        members = 0
        for v in self.member.values():
            members += 1
            korean += v['korean']
            english += v['english']
            math += v['math']
        korean_avg = korean/members
        english_avg = english/members
        math_avg = math/members
        print('korean 성적 합계',korean)
        print('english 성적 합계',english)
        print('math 성적 합계',math)
        print('korean 성적 평균',korean_avg)
        print('english 성적 평균',english_avg)
        print('math 성적 평균',math_avg)
    
    def check_no(self,x=0):
        if x == 0:
            for i in self.member:
                print('학번:',i,'이름 :',self.member[i]['name'])
        else:
            dic = {}
            for k,v in student.member.items():
                dic[v['name']] = k
            print(f'학번은 {dic[x]}입니다')
    def change_password(self,password):
        self.member[self.id_][self.password] = password
        print(f'{self.password}가 {password}로 바뀌었습니다.)
        
        else:
              print('비밀번호를 확인하세요')
    else:
        print(f'{self.id_}학번은 등록이 안되어 있습니다 관리자에게 확인하세요)

# %%
student = Student_score()
# Out:
# 아이디를 입력하세요 admin
# 비밀번호를 입력하세요 0000
#         메뉴
#         ================
#         성적 조회 : 1
#         성적 입력 : 2
#         학번 조회 : 3
#         ================
# 작업을 선택하세요 2
# 이름을 입력하세요 이강욱
# 학생비밀번를 입력하세요 1
# 국어 성적을 입력하세요 100
# 영어 성적을 입력하세요 100
# 수학성적을 입력하세요 100
# 계속하시려면 엔터키를 치시고 끝내시려면 아무 문자나 입력하세요
# 이름을 입력하세요 이현오

# %%
class List:
    def __int__(self,*x)

# %%
a = list([1,2,3])
