# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
sigmoid(0)
# Out:
# 0.5

# %%
x = np.linspace(-5,5,30)
y = sigmoid(x)

# %%
plt.plot(x,y)

# %%
x = np.array([1,1,1,2,2,2,3,3,3])

# %%
x
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3])

# %%
np.random.choice(x,4)
# Out:
# array([2, 2, 1, 1])

# %%
samples = []
for i in range(1000):
    samples.append(np.random.choice(x,4).mean())
samples = np.array(samples)

# %%
samples
# Out:
# array([2.75, 1.5 , 2.  , 2.  , 1.  , 1.75, 2.5 , 1.25, 2.25, 1.25, 1.75,
#        1.5 , 2.75, 1.5 , 2.25, 2.  , 2.  , 1.75, 2.25, 1.75, 1.5 , 2.  ,
#        2.  , 1.75, 2.  , 1.75, 2.25, 2.25, 1.75, 2.25, 2.  , 1.5 , 1.75,
#        1.5 , 1.5 , 2.25, 2.25, 1.75, 1.75, 2.5 , 2.25, 2.  , 1.5 , 1.5 ,
#        2.  , 2.  , 2.  , 1.75, 1.75, 2.  , 1.5 , 1.75, 2.25, 2.  , 2.5 ,
#        2.5 , 2.25, 1.25, 2.75, 1.75, 1.  , 1.25, 2.5 , 1.75, 2.  , 2.25,
#        2.25, 2.  , 2.  , 2.  , 2.  , 2.  , 2.75, 2.25, 2.5 , 2.  , 2.5 ,
#        2.  , 1.75, 2.25, 1.5 , 1.75, 2.25, 2.5 , 2.5 , 2.25, 2.5 , 2.5 ,
#        1.25, 1.75, 2.25, 2.5 , 1.75, 2.25, 2.  , 2.  , 2.  , 1.75, 2.25,
#        1.5 , 2.25, 2.5 , 1.  , 3.  , 2.5 , 2.5 , 2.25, 2.  , 1.5 , 1.25,
#        2.  , 2.25, 1.75, 2.25, 1.5 , 1.5 , 2.25, 2.  , 2.  , 1.5 , 1.25,
#        2.  , 1.25, 2.  , 2.  , 1.5 , 2.25, 1.25, 1.5 , 2.25, 2.25, 1.75,
#        1.25, 2.  , 2.5 , 2.5 , 2.  , 2.  , 2.  , 2.25, 2.25, 2.25, 2.25,
# ...

# %%
plt.hist(samples)
# Out:
# (array([ 12.,  55., 135., 186.,   0., 238., 192., 117.,  46.,  19.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.array([1,1,1,2,2,2,3,3,3])

samples = []
for i in range(1000):
    samples.append(np.random.choice(x,4).mean())
samples = np.array(samples)

samples
# Out:
# array([2.25, 1.5 , 1.5 , 2.  , 2.75, 1.25, 1.75, 2.  , 2.  , 2.25, 2.75,
#        2.  , 2.5 , 2.75, 1.25, 1.75, 2.25, 1.5 , 1.75, 2.  , 2.5 , 2.25,
#        1.75, 1.75, 2.  , 1.25, 2.25, 2.5 , 2.25, 1.75, 2.25, 2.  , 1.5 ,
#        1.75, 1.75, 2.25, 2.  , 1.75, 2.  , 1.5 , 2.  , 2.5 , 2.25, 2.25,
#        1.25, 1.75, 2.25, 1.25, 2.75, 1.5 , 1.5 , 1.75, 1.75, 1.5 , 2.  ,
#        1.5 , 2.5 , 2.25, 2.5 , 2.  , 2.5 , 2.75, 2.5 , 1.75, 1.75, 2.  ,
#        2.25, 1.75, 2.25, 2.75, 2.25, 2.  , 2.  , 2.  , 1.25, 2.75, 2.5 ,
#        1.5 , 2.5 , 1.75, 2.  , 2.  , 2.75, 1.5 , 2.5 , 2.25, 2.5 , 2.  ,
#        2.  , 1.75, 2.  , 2.25, 1.5 , 1.5 , 1.75, 2.25, 2.25, 2.  , 1.5 ,
#        2.25, 1.25, 2.  , 1.5 , 2.5 , 2.25, 2.75, 1.75, 1.25, 2.75, 1.75,
#        1.5 , 2.  , 2.  , 2.  , 1.25, 1.75, 2.  , 2.5 , 2.25, 2.75, 1.75,
#        1.5 , 1.25, 2.25, 2.  , 2.  , 2.  , 2.  , 2.25, 2.  , 2.75, 2.  ,
#        1.25, 2.75, 2.  , 2.  , 1.5 , 2.5 , 2.75, 1.5 , 2.5 , 2.  , 1.75,
# ...

# %%
x = np.random.uniform(0,1,1000)

# %%
x
# Out:
# array([0.98100173, 0.21506115, 0.56401304, 0.70220428, 0.02483691,
#        0.8897755 , 0.4060189 , 0.30723114, 0.86485305, 0.0425727 ,
#        0.12392035, 0.49459201, 0.54809774, 0.34700344, 0.2165989 ,
#        0.94980471, 0.78961553, 0.58073682, 0.15207442, 0.36967372,
#        0.29002566, 0.13015726, 0.02406263, 0.25481962, 0.3365349 ,
#        0.33206272, 0.80498525, 0.04012971, 0.9952599 , 0.81766583,
#        0.5174896 , 0.24787759, 0.94641399, 0.71259019, 0.05126733,
#        0.51161859, 0.4480735 , 0.61433356, 0.17757657, 0.58935596,
#        0.27623523, 0.93207729, 0.90968343, 0.30061926, 0.75622417,
#        0.44962153, 0.49992126, 0.25886094, 0.28263983, 0.17822545,
#        0.67216409, 0.89190959, 0.18217607, 0.63265876, 0.71301807,
#        0.16980852, 0.18167558, 0.41735128, 0.67876849, 0.21454585,
#        0.08724325, 0.83154134, 0.38269066, 0.23375683, 0.94965474,
#        0.72114805, 0.61152896, 0.06584815, 0.91992502, 0.74151691,
# ...

# %%
plt.hist(x,bins=100)
# Out:
# (array([13.,  2., 13.,  6., 11.,  7., 14., 10., 15.,  7.,  8., 14., 12.,
#          3.,  5., 19.,  9., 12., 15.,  9.,  9., 13.,  9.,  9., 13., 14.,
#         13.,  9., 11., 10., 12.,  7.,  4., 15., 11., 10., 11., 15., 11.,
#         11.,  5.,  9.,  9.,  9., 13., 11.,  9.,  5., 11.,  7., 10., 11.,
#          9.,  8.,  7.,  8.,  9., 10., 12., 12., 13., 13.,  7.,  8., 10.,
#          8.,  9., 14., 10.,  7., 13.,  8.,  9., 10.,  9., 11., 13.,  7.,
#          8., 10.,  9.,  8.,  6.,  9., 11., 11.,  8., 17., 11., 14.,  2.,
#         14., 10.,  9.,  8.,  5., 11., 10.,  7., 18.]),
#  array([0.00173856, 0.011713  , 0.02168744, 0.03166188, 0.04163632,
#         0.05161076, 0.0615852 , 0.07155964, 0.08153408, 0.09150852,
#         0.10148296, 0.1114574 , 0.12143184, 0.13140628, 0.14138072,
#         0.15135516, 0.1613296 , 0.17130404, 0.18127848, 0.19125292,
#         0.20122736, 0.2112018 , 0.22117624, 0.23115068, 0.24112512,
# ...

# %%
x = np.random.uniform(0,1,1000)
plt.hist(x,bins=30)
# Out:
# (array([30., 35., 21., 28., 38., 43., 17., 36., 36., 26., 24., 21., 30.,
#         49., 37., 37., 46., 30., 34., 33., 39., 33., 27., 40., 34., 41.,
#         36., 30., 35., 34.]),
#  array([4.27213445e-05, 3.33724983e-02, 6.67022752e-02, 1.00032052e-01,
#         1.33361829e-01, 1.66691606e-01, 2.00021383e-01, 2.33351160e-01,
#         2.66680937e-01, 3.00010714e-01, 3.33340490e-01, 3.66670267e-01,
#         4.00000044e-01, 4.33329821e-01, 4.66659598e-01, 4.99989375e-01,
#         5.33319152e-01, 5.66648929e-01, 5.99978706e-01, 6.33308483e-01,
#         6.66638259e-01, 6.99968036e-01, 7.33297813e-01, 7.66627590e-01,
#         7.99957367e-01, 8.33287144e-01, 8.66616921e-01, 8.99946698e-01,
#         9.33276475e-01, 9.66606252e-01, 9.99936029e-01]),
#  <BarContainer object of 30 artists>)

# %%
samples = []
for i in range(100):
    samples.append(np.random.choice(x,30).mean())

# %%
plt.hist(np.array(x),bins=30)
# Out:
# (array([30., 35., 21., 28., 38., 43., 17., 36., 36., 26., 24., 21., 30.,
#         49., 37., 37., 46., 30., 34., 33., 39., 33., 27., 40., 34., 41.,
#         36., 30., 35., 34.]),
#  array([4.27213445e-05, 3.33724983e-02, 6.67022752e-02, 1.00032052e-01,
#         1.33361829e-01, 1.66691606e-01, 2.00021383e-01, 2.33351160e-01,
#         2.66680937e-01, 3.00010714e-01, 3.33340490e-01, 3.66670267e-01,
#         4.00000044e-01, 4.33329821e-01, 4.66659598e-01, 4.99989375e-01,
#         5.33319152e-01, 5.66648929e-01, 5.99978706e-01, 6.33308483e-01,
#         6.66638259e-01, 6.99968036e-01, 7.33297813e-01, 7.66627590e-01,
#         7.99957367e-01, 8.33287144e-01, 8.66616921e-01, 8.99946698e-01,
#         9.33276475e-01, 9.66606252e-01, 9.99936029e-01]),
#  <BarContainer object of 30 artists>)

# %%
x = np.random.uniform(0,1,1000)

plt.hist(x,bins=100)
# Out:
# (array([14., 13., 10.,  5.,  9.,  8.,  9.,  6., 14.,  8.,  9., 10., 11.,
#         13.,  8.,  9., 11., 15., 12.,  6., 16.,  8.,  9., 14., 15., 11.,
#         11., 16., 12.,  9., 10.,  9.,  7.,  8.,  9.,  8.,  9.,  8., 13.,
#         10.,  5., 13., 10.,  9., 15., 11., 14., 15.,  8., 13.,  6., 14.,
#          9., 13.,  3.,  9.,  5.,  8.,  4., 12.,  9.,  6.,  9., 12., 13.,
#         10.,  9.,  6.,  9.,  8.,  8., 13.,  7., 11., 11.,  9., 11., 15.,
#          9.,  6., 11., 18.,  9., 11.,  9.,  6.,  8., 13.,  6., 10., 13.,
#         14., 13.,  6.,  9.,  3.,  9., 14.,  6., 13.]),
#  array([1.47090534e-04, 1.01346767e-02, 2.01222629e-02, 3.01098491e-02,
#         4.00974353e-02, 5.00850215e-02, 6.00726077e-02, 7.00601940e-02,
#         8.00477802e-02, 9.00353664e-02, 1.00022953e-01, 1.10010539e-01,
#         1.19998125e-01, 1.29985711e-01, 1.39973297e-01, 1.49960884e-01,
#         1.59948470e-01, 1.69936056e-01, 1.79923642e-01, 1.89911228e-01,
# ...

# %%
255**4
# Out:
# 4228250625

# %%
from IPython.display import HTML, YouTubeVideo

# %%
HTML('http://naver.com')
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
YouTubeVideo('https://www.youtube.com/watch?v=MsmeAac-RJ4')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=MsmeAac-RJ4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
